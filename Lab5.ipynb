# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
import pandas as pd

data = pd.read_excel(r"C:\Users\Lenovo\OneDrive\Documents\ML Dataset.xlsx")

# %%
data1=data.iloc[:,1]
print(data1)
# Out:
# 0       0.343874
# 1       0.084930
# 2       0.216801
# 3       0.095572
# 4       0.300674
#           ...
# 1121    0.126331
# 1122    0.060391
# 1123    0.197136
# 1124    0.075891
# 1125    0.099571
# Name: embed_1, Length: 1126, dtype: float64

# %%
data2=data.iloc[:,2]
print(data2)
# Out:
# 0       0.176382
# 1       0.047369
# 2       0.029110
# 3       0.157358
# 4       0.366119
#           ...
# 1121    0.084587
# 1122   -0.009947
# 1123    0.149639
# 1124    0.100093
# 1125    0.229438
# Name: embed_2, Length: 1126, dtype: float64

# %%
import numpy as np

full_dataset = np.concatenate((data1, data2), axis=0)
mean_data1 = np.mean(data1, axis=0)
mean_data2 = np.mean(data2, axis=0)

std_data1 = np.std(data1, axis=0)
std_data2 = np.std(data2, axis=0)

distance_between_classes = np.linalg.norm(mean_data1 - mean_data2)

print("Mean  for data1:", mean_data1)
print("Mean  for data2:", mean_data2)
print(" sigma for data1:", std_data1)
print(" sigmafor data2:", std_data2)
print("Distance between mean vectors :", distance_between_classes)
# Out:
# Mean  for data1: 0.13016513112965425
# Mean  for data2: 0.10341144222269379
#  sigma for data1: 0.1460608227588885
#  sigmafor data2: 0.17069689278001857
# Distance between mean vectors : 0.026753688906960463

# %%
import matplotlib.pyplot as plt

data3 = data.iloc[:, 3]
plt.hist(data3, bins=10, color='blue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Data3')
plt.xlabel('Feature Values')
plt.show()
mean_value = np.mean(data3)
variance_value = np.var(data3)

print(f"Mean: {mean_value}")
print(f"Variance: {variance_value}")
# Out:
# Mean: 0.20161629742652232
# Variance: 0.020627186462260028

# %%
data4=data.iloc[:,4]
data5=data.iloc[:,5]
r_values = np.arange(1, 11)

from scipy.spatial import distance
distances = [distance.minkowski(data4,data5, p=r) for r in r_values]

plt.plot(r_values, distances, marker='o')
plt.title('Minkowski Distance vs. r')
plt.xlabel('r')
plt.ylabel('Minkowski Distance')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split


features = data.iloc[:, 0:383]
target = data.iloc[:,384]
target = target.astype(int)
print("targeted coloumn",target)
print(features)
X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.3,random_state=42)
# Out:
# targeted coloumn 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1121    5
# 1122    5
# 1123    5
# 1124    5
# 1125    5
# Name: output, Length: 1126, dtype: int64
#        embed_0   embed_1   embed_2   embed_3   embed_4   embed_5   embed_6  \
# 0    -0.089926  0.343874  0.176382  0.169358 -0.413337 -0.276315  0.188070
# 1     0.303261  0.084930  0.047369 -0.017244 -0.524733 -0.104934  0.335107
# 2    -0.274291  0.216801  0.029110  0.259279 -0.655594 -0.289643  0.073369
# 3     0.118676  0.095572  0.157358  0.225097 -0.632885 -0.125629  0.204013
# 4     0.298772  0.300674  0.366119 -0.022142 -0.748852 -0.035268  0.277504
# ...        ...       ...       ...       ...       ...       ...       ...
# 1121 -0.316305  0.126331  0.084587  0.099225 -0.503260 -0.062559  0.115574
# 1122 -0.342471  0.060391 -0.009947  0.156623 -0.511338 -0.070624  0.140290
# 1123 -0.379174  0.197136  0.149639  0.060261 -0.347212 -0.064022  0.119379
# 1124 -0.379726  0.075891  0.100093  0.118006 -0.429774 -0.140415  0.120826
# 1125 -0.279187  0.099571  0.229438  0.197775 -0.326235 -0.254882 -0.000509
#
#        embed_7   embed_8   embed_9  ...  embed_373  embed_374  embed_375  \
# 0     0.094621  0.330203 -0.258730  ...  -0.162384   0.544121  -0.272278
# 1    -0.081476  0.213762 -0.105293  ...   0.010469   0.238566  -0.310262
# 2     0.014463  0.104336 -0.014190  ...  -0.031160   0.376746  -0.464926
# 3     0.074028  0.149310 -0.147779  ...   0.080215   0.021368  -0.030543
# 4     0.075697  0.055439 -0.200804  ...   0.111025  -0.060740  -0.149575
# ...        ...       ...       ...  ...        ...        ...        ...
# 1121  0.012244  0.254925 -0.056957  ...   0.029401   0.333122  -0.514027
# 1122  0.027731  0.275638 -0.068072  ...  -0.003455   0.325357  -0.595396
# 1123  0.019028  0.268377 -0.188386  ...   0.015981   0.375112  -0.517010
# 1124  0.074879  0.154743 -0.030652  ...   0.050510   0.321034  -0.683223
# 1125  0.034733  0.283212 -0.207798  ...   0.007155   0.396871  -0.574962
#
#       embed_376  embed_377  embed_378  embed_379  embed_380  embed_381  \
# 0     -0.230662   0.173143  -0.259786  -0.316996  -0.389919   0.105596
# 1     -0.090271   0.129022  -0.008138  -0.220774  -0.021343  -0.029695
# 2     -0.117493  -0.118993  -0.046860   0.010008  -0.118400  -0.085768
# 3     -0.100965   0.236099  -0.286450  -0.130198  -0.051258  -0.047492
# 4     -0.230057   0.296528  -0.526185  -0.251471   0.196795  -0.101786
# ...         ...        ...        ...        ...        ...        ...
# 1121  -0.316320   0.013955  -0.030025  -0.306975   0.139429  -0.256867
# 1122  -0.419794   0.061882  -0.190783  -0.323777   0.185546  -0.144995
# 1123  -0.354851   0.093440  -0.093673  -0.271739   0.042851  -0.143179
# 1124  -0.428964   0.052585  -0.172558  -0.218717   0.201938  -0.085569
# 1125  -0.275116  -0.012660   0.011353  -0.323538   0.055882   0.001314
#
#       embed_382
# 0      0.196438
# 1      0.335977
# 2      0.512956
# 3      0.241473
# 4      0.570922
# ...         ...
# 1121   0.331288
# 1122   0.347215
# 1123   0.410811
# 1124   0.345646
# 1125   0.474825
#
# [1126 rows x 383 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
# Assuming X_train and y_train are already defined
knn_classifier = KNeighborsClassifier(n_neighbors=3)
knn_classifier.fit(X_train, y_train)
y_pred = knn_classifier.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.4171597633136095
